# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

print(tf.__version__)

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# 2.18.0

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Flatten the 28x28 images to 784 features
    Dense(128, activation='relu'),  # First hidden layer with 128 neurons
    Dense(64, activation='relu'),   # Second hidden layer with 64 neurons
    Dense(10, activation='softmax')  # Output layer for 10 classes
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7805 - loss: 0.6283 - val_accuracy: 0.8487 - val_loss: 0.4187
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8598 - loss: 0.3800 - val_accuracy: 0.8356 - val_loss: 0.4358
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8755 - loss: 0.3368 - val_accuracy: 0.8673 - val_loss: 0.3683
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8830 - loss: 0.3168 - val_accuracy: 0.8732 - val_loss: 0.3469
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8902 - loss: 0.2950 - val_accuracy: 0.8793 - val_loss: 0.3352
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8947 - loss: 0.2824 - val_accuracy: 0.8666 - val_loss: 0.3570
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8992 - loss: 0.2651 - val_accuracy: 0.8793 - val_loss: 0.3385
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9028 - loss: 0.2567 - val_accuracy: 0.8819 - val_loss: 0.3378
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9065 - loss: 0.2460 - val_accuracy: 0.8815 - val_loss: 0.3372
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9121 - loss: 0.2323 - val_accuracy: 0.8756 - val_loss: 0.3480

# %%
print(history.history["accuracy"])
print(history.history["val_accuracy"])

print(history.history["loss"])
print(history.history["val_loss"])

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [0.8232499957084656, 0.8633833527565002, 0.8759999871253967, 0.8844500184059143, 0.8911166787147522, 0.8950166702270508, 0.8977833390235901, 0.9031500220298767, 0.9059333205223083, 0.9103333353996277]
# [0.8486999869346619, 0.8356000185012817, 0.8672999739646912, 0.873199999332428, 0.8792999982833862, 0.866599977016449, 0.8792999982833862, 0.8819000124931335, 0.8815000057220459, 0.8755999803543091]
# [0.49425700306892395, 0.373680055141449, 0.33683323860168457, 0.3117174208164215, 0.2945041358470917, 0.28088465332984924, 0.2692510783672333, 0.2558744549751282, 0.24796143174171448, 0.2372477799654007]
# [0.418702095746994, 0.4358384311199188, 0.3683106005191803, 0.34688493609428406, 0.33516231179237366, 0.3569553792476654, 0.33852970600128174, 0.33784419298171997, 0.33721983432769775, 0.34797385334968567]
