# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

print(tf.__version__)

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# WARNING:tensorflow:From C:\Users\darke\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0
# ...
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Flatten the 28x28 images to 784 features
    Dense(128, activation='relu'),  # First hidden layer with 128 neurons
    Dense(64, activation='relu'),   # Second hidden layer with 64 neurons
    Dense(10, activation='softmax')  # Output layer for 10 classes
])

model.compile(optimizer=Adam(learning_rate=0.001), #We recommend adjusting this based on your hardware for a better experience  
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = Sequential([
#       2     Flatten(input_shape=(28, 28)),  # Flatten the 28x28 images to 784 features
#       3     Dense(128, activation='relu'),  # First hidden layer with 128 neurons
#       4     Dense(64, activation='relu'),   # Second hidden layer with 64 neurons
#       5     Dense(10, activation='softmax')  # Output layer for 10 classes
#       6 ])
#       8 model.compile(optimizer=Adam(learning_rate=0.1),
#       9               loss='sparse_categorical_crossentropy',
#      10               metrics=['accuracy'])
#
# NameError: name 'Sequential' is not defined

# %%
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), batch_size=32) #Here you can optimize you batch_size for you hardware(memory)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4920 - accuracy: 0.8245 - val_loss: 0.5019 - val_accuracy: 0.8144
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3699 - accuracy: 0.8650 - val_loss: 0.4067 - val_accuracy: 0.8514
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3352 - accuracy: 0.8769 - val_loss: 0.3630 - val_accuracy: 0.8710
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3094 - accuracy: 0.8856 - val_loss: 0.3427 - val_accuracy: 0.8807
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2909 - accuracy: 0.8918 - val_loss: 0.3409 - val_accuracy: 0.8797
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2774 - accuracy: 0.8967 - val_loss: 0.3445 - val_accuracy: 0.8769
# Epoch 7/10
# ...

# %%
#plotting the training and validation error and accuracy metrics
print(history.history["accuracy"])
print(history.history["val_accuracy"])

print(history.history["loss"])
print(history.history["val_loss"])

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.show()

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [0.826449990272522, 0.865066647529602, 0.8775333166122437, 0.883983314037323, 0.8909833431243896, 0.8956999778747559, 0.8993833065032959, 0.9048166871070862, 0.9081000089645386, 0.909416675567627]
# [0.8384000062942505, 0.8619999885559082, 0.870199978351593, 0.8687000274658203, 0.8715999722480774, 0.8723000288009644, 0.8765000104904175, 0.8776000142097473, 0.8707000017166138, 0.8788999915122986]
# [0.49255606532096863, 0.36795762181282043, 0.33302637934684753, 0.3102204501628876, 0.2932586669921875, 0.27979153394699097, 0.2673613429069519, 0.25701090693473816, 0.24714867770671844, 0.2394234985113144]
# [0.4400753974914551, 0.38109150528907776, 0.3609468936920166, 0.3618257939815521, 0.34771600365638733, 0.3449494242668152, 0.3543050289154053, 0.34048062562942505, 0.3677944839000702, 0.3503274917602539]
